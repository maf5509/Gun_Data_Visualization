# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
gun_d = pd.read_csv('C://Users//fergu//full_gun_data.csv')
gun_d.head()
# Out:
#    Unnamed: 0  year  month   intent  police sex   age                    race  \
# 0           1  2012      1  Suicide       0   M  34.0  Asian/Pacific Islander
# 1           2  2012      1  Suicide       0   F  21.0                   White
# 2           3  2012      1  Suicide       0   M  60.0                   White
# 3           4  2012      2  Suicide       0   M  64.0                   White
# 4           5  2012      2  Suicide       0   M  31.0                   White
#
#    hispanic            place     education
# 0       100             Home           BA+
# 1       100           Street  Some college
# 2       100  Other specified           BA+
# 3       100             Home           BA+
# 4       100  Other specified        HS/GED

# %%
gun_d.describe()
# Out:
#           Unnamed: 0           year          month         police  \
# count  100798.000000  100798.000000  100798.000000  100798.000000
# mean    50399.500000    2013.000357       6.567601       0.013909
# std     29098.020554       0.816278       3.405609       0.117114
# min         1.000000    2012.000000       1.000000       0.000000
# 25%     25200.250000    2012.000000       4.000000       0.000000
# 50%     50399.500000    2013.000000       7.000000       0.000000
# 75%     75598.750000    2014.000000       9.000000       0.000000
# max    100798.000000    2014.000000      12.000000       1.000000
#
#                  age       hispanic
# count  100780.000000  100798.000000
# mean       43.857601     114.179607
# std        19.496181      61.595734
# min         0.000000     100.000000
# 25%        27.000000     100.000000
# 50%        42.000000     100.000000
# 75%        58.000000     100.000000
# max       107.000000     998.000000

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y="police", hue="race", data=gun_d, palette="bright")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y="year", hue="race", data=gun_d, palette="bright")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y="race", hue="year", data=gun_d, palette="pastel")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y="intent", hue="year", data=gun_d, palette="pastel")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y="intent", hue="education", data=gun_d, palette="pastel")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="year", y="age", hue='race', data=gun_d)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="year", y="age", hue='intent', data=gun_d)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="year", y="age", hue="race", data=gun_d, palette='muted')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="year", y="age", hue="education", data=gun_d, palette='muted')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="year", y="age", hue="police", data=gun_d, palette='muted')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x="race", y="age", data=gun_d, jitter=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x="intent", y="age", data=gun_d, jitter=True)
plt.xticks(rotation=90)
plt.show()

# %%
y2012 = gun_d['year'] == 2012# & ~np.isnan(gun_d['age'])
gun_d2012 = gun_d[y2012]
gun_d2012fin = ~np.isnan(gun_d2012['age'])
gun_d2012final = gun_d2012[gun_d2012fin]

y2013 = gun_d['year'] == 2013# & ~np.isnan(gun_d['age'])
gun_d2013 = gun_d[y2013]
gun_d2013fin = ~np.isnan(gun_d2013['age'])
gun_d2013final = gun_d2013[gun_d2013fin]

y2014 = gun_d['year'] == 2014# & ~np.isnan(gun_d['age'])
gun_d2014 = gun_d[y2014]
gun_d2014fin = ~np.isnan(gun_d2014['age'])
gun_d2014final = gun_d2014[gun_d2014fin]

gun_d2012final.head()
# Out:
#    Unnamed: 0  year  month   intent  police sex   age                    race  \
# 0           1  2012      1  Suicide       0   M  34.0  Asian/Pacific Islander
# 1           2  2012      1  Suicide       0   F  21.0                   White
# 2           3  2012      1  Suicide       0   M  60.0                   White
# 3           4  2012      2  Suicide       0   M  64.0                   White
# 4           5  2012      2  Suicide       0   M  31.0                   White
#
#    hispanic            place     education
# 0       100             Home           BA+
# 1       100           Street  Some college
# 2       100  Other specified           BA+
# 3       100             Home           BA+
# 4       100  Other specified        HS/GED

# %%
plt.figure(figsize=(18, 3))

#distplot plots kernel density estimate by default. for reg histogram set to False
plt.subplot(1, 3, 1)
#plt.ylim(0,110)
sns.distplot(gun_d2012final['age'], bins=10)#, kde=True, rug=True)
plt.xlabel('Age of Victim')
plt.ylabel('Frequency')
plt.title('2012 US Gun Deaths - Age Distribution')

#add a rug plot
plt.subplot(1,3,2)
#plt.ylim(0,110)
sns.distplot(gun_d2013final['age'], bins=10)#, kde=True, rug=True)
plt.xlabel('Age of Victim')
plt.ylabel('Frequency')
plt.title('2013 US Gun Deaths - Age Distribution')

plt.subplot(1,3,3)
#plt.ylim(0,110)
sns.distplot(gun_d2014final['age'], bins=10)#, kde=True, rug=True)
plt.xlabel('Age of Victim')
plt.ylabel('Frequency')
plt.title('2014 US Gun Deaths - Age Distribution')

plt.show()

# %%
yacc = gun_d['intent'] == 'Accidental'
gun_dacc = gun_d[yacc]
gun_daccfin = ~np.isnan(gun_dacc['age'])
gun_daccfinal = gun_dacc[gun_daccfin]

yhom = gun_d['intent'] == 'Homicide'
gun_dhom = gun_d[yhom]
gun_dhomfin = ~np.isnan(gun_dhom['age'])
gun_dhomfinal = gun_dhom[gun_dhomfin]

ysui = gun_d['intent'] == 'Suicide'
gun_dsui = gun_d[ysui]
gun_dsuifin = ~np.isnan(gun_dsui['age'])
gun_dsuifinal = gun_dsui[gun_dsuifin]

yund = gun_d['intent'] == 'Undetermined'
gun_dund = gun_d[yund]
gun_dundfin = ~np.isnan(gun_dund['age'])
gun_dundfinal = gun_dund[gun_dundfin]

gun_dhomfinal.head()
# Out:
#     Unnamed: 0  year  month    intent  police sex   age  \
# 14          15  2012      3  Homicide       0   M  27.0
# 18          19  2012      3  Homicide       0   M  31.0
# 22          23  2012      4  Homicide       0   F  47.0
# 24          25  2012      4  Homicide       0   M  51.0
# 25          26  2012      4  Homicide       0   M  41.0
#
#                       race  hispanic            place     education
# 14                   White       100             Home        HS/GED
# 18  Asian/Pacific Islander       100             Home  Some college
# 22                   Black       100             Home        HS/GED
# 24                   White       100  Other specified        HS/GED
# 25                   White       100  Other specified        HS/GED

# %%
plt.figure(figsize=(18, 10))

#distplot plots kernel density estimate by default. for reg histogram set to False
plt.subplot(2,2,1)
sns.distplot(gun_daccfinal['age'], bins=10)#, kde=True, rug=True)
plt.xlabel('Age of Victim')
plt.ylabel('Frequency')
plt.title('US Accidental Gun Deaths - Age Distribution')

#add a rug plot
plt.subplot(2,2,2)
sns.distplot(gun_dhomfinal['age'], bins=10)#, kde=True, rug=True)
plt.xlabel('Age of Victim')
plt.ylabel('Frequency')
plt.title('US Homicide Gun Deaths - Age Distribution')

plt.subplot(2,2,3)
sns.distplot(gun_dsuifinal['age'], bins=10)#, kde=True, rug=True)
plt.xlabel('Age of Victim')
plt.ylabel('Frequency')
plt.title('US Suicide Gun Deaths - Age Distribution')

plt.subplot(2,2,4)
sns.distplot(gun_dundfinal['age'], bins=10)#, kde=True, rug=True)
plt.xlabel('Age of Victim')
plt.ylabel('Frequency')
plt.title('US Gun Deaths (Manner Undetermined) - Age Distribution')

plt.show()

# %%
state_shoot = pd.read_csv('C://Users//fergu//states2.csv')
state_shoot.head()
# Out:
#         state  laws per state  shooting victim per capita      State2  \
# 0     Alabama            10.0                    1.066917     Alabama
# 1      Alaska             4.0                    0.563183      Alaska
# 2     Arizona            11.0                    1.314080     Arizona
# 3    Arkansas            11.0                    1.131704    Arkansas
# 4  California           106.0                    1.436130  California
#
#    population  total victims
# 0     4780127           51.0
# 1      710249            4.0
# 2     6392307           84.0
# 3     2915958           33.0
# 4    37252895          535.0

# %%
plt.figure(figsize=(20,16))
sns.jointplot(x='population', y='total victims', data=state_shoot)
plt.title('US No. of Shooting Victims vs. State Population, Time Period Unknown')
plt.subplots_adjust(hspace = -0.3)
#plt.xlabel('Population')
#plt.ylabel('Total Victims')
plt.show()
